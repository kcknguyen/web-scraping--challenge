# %%
from bs4 import BeautifulSoup 
import requests
import pandas as pd
from splinter import Browser
from webdriver_manager.chrome import ChromeDriverManager
import pymongo
import time

# %%
#pointing to the directory where chromedriver exists
# splinter
executable_path = {"executable_path": "/Users/chromedriver"}
browser = Browser("chrome", **executable_path, headless=False)

# %%
# URL for the page to be scraped
url="https://mars.nasa.gov/news/"

# %%
#open browser page
browser.visit(url)
browser = browser.html
time.sleep(1)
# Create BeautifulSoup object
news_soup = BeautifulSoup(browser, 'html.parser')
print(soup.prettify())
browser.quit()
# Out:
# <html lang="en">
#  <head>
#   <link href="//ajax.googleapis.com/ajax/libs/jqueryui/1.11.3/themes/smoothness/jquery-ui.css" rel="stylesheet" type="text/css"/>
#   <title>
#    Astropedia Search Results | USGS Astrogeology Science Center
#   </title>
#   <meta content="USGS Astrogeology Science Center Astropedia search results." name="description"/>
#   <meta content="USGS,Astrogeology Science Center,Cartography,Geology,Space,Geological Survey,Mapping" name="keywords"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
#   <meta content="x61hXXVj7wtfBSNOPnTftajMsZ5yB2W-qRoyr7GtOKM" name="google-site-verification"/>
#   <!--<link rel="stylesheet" href="http://fonts.googleapis.com/css?family=Open+Sans:400italic,400,bold"/>-->
#   <link href="/css/main.css" media="screen" rel="stylesheet"/>
# ...

# %%
# Scaping lastest News Title
news_titles = news_soup.find('div', class_='list_text').find('div', class_ = 'content_title').text
print(news_titles)

# %%
# Scaping Paragraph text
teaser_article = news_soup.find('div', class_='article_teaser_body').text
print(teaser_article)

# %%
# Scaping Space Image
jpl_mars_url = "https://www.jpl.nasa.gov"
image_url = "https://www.jpl.nasa.gov/spaceimages/?search=&category=Mars"
# splinter
executable_path = {"executable_path": "/Users/chromedriver"}
browser = Browser("chrome", **executable_path, headless=False)
browser.visit(featured_image_url)
image_html = browser.html
images_soup = BeautifulSoup(browser, 'html.parser')

# %%
# Retrieve image
image_pathway = images_soup.find('imag')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-64-4b3e8b61c28c> in <module>
#       1 # Retrieve image
# ----> 2 image_pathway = images_soup.find('imag')
#
# NameError: name 'images_soup' is not defined

# %%
## Mars facts to scraping
mars_facts_url = "https://space-facts.com/mars"
mars_info_tables = pd.read_html (mars_facts_url)
print (mars_info_tables)
# Out:
# [                      0                              1
# 0  Equatorial Diameter:                       6,792 km
# 1       Polar Diameter:                       6,752 km
# 2                 Mass:  6.39 × 10^23 kg (0.11 Earths)
# 3                Moons:            2 (Phobos & Deimos)
# 4       Orbit Distance:       227,943,824 km (1.38 AU)
# 5         Orbit Period:           687 days (1.9 years)
# 6  Surface Temperature:                   -87 to -5 °C
# 7         First Record:              2nd millennium BC
# 8          Recorded By:           Egyptian astronomers,   Mars - Earth Comparison             Mars            Earth
# 0               Diameter:         6,779 km        12,742 km
# 1                   Mass:  6.39 × 10^23 kg  5.97 × 10^24 kg
# 2                  Moons:                2                1
# 3      Distance from Sun:   227,943,824 km   149,598,262 km
# 4         Length of Year:   687 Earth days      365.24 days
# ...

# %%
mars_description_df = mars_info_tables[0]
mars_description_df.columns = ["Mars Description", "Value"]
mars_description_df
# Out:
#        Mars Description                          Value
# 0  Equatorial Diameter:                       6,792 km
# 1       Polar Diameter:                       6,752 km
# 2                 Mass:  6.39 × 10^23 kg (0.11 Earths)
# 3                Moons:            2 (Phobos & Deimos)
# 4       Orbit Distance:       227,943,824 km (1.38 AU)
# 5         Orbit Period:           687 days (1.9 years)
# 6  Surface Temperature:                   -87 to -5 °C
# 7         First Record:              2nd millennium BC
# 8          Recorded By:           Egyptian astronomers

# %%
# Mars hemispheres scraping
mars_hemispheres_url = "https://astrogeology.usgs.gov/search/results?q=hemisphere+enhanced&k1=target&v1=Mars"
# splinter
executable_path = {"executable_path": "/Users/chromedriver"}
browser = Browser("chrome", **executable_path, headless=False)
browser.visit(mars_hemispheres_url)
hemispheres_html = browser.html
mars_hemispheres_soup = BeautifulSoup(hemispheres_html,'html.parser')

# %%
all_mars_hemispheres = mars_hemispheres_soup.find_all('div', class_='item')

all_mars_image_hemispheres_url = []

url_image = 'https://astrogeology.usgs.gov'

hemispheres = ["Valles Marineris Hemisphere", "Cerberus Hemisphere", "Schiaparelli Hemisphere", "Syrtis Major Hemisphere"] 
#looping
for hemispheres in all_mars_hemispheres:
    hemisphere = hemispheres.find('div', class_="description")
    title = hemisphere.h3.text
    hemisphere_link = hemispheres.a["href"]
    browser.visit(mars_hemispheres_url + hemisphere_link )
    #get the html
    hemp_image_html = browser.html
    hemp_image_soup = BeautifulSoup(hemp_image_html, 'html.parser')
    #find image and link 
    image = hemp_image_soup.find('div', class_='downloads')
    image_link = image.find('li').a['href']
    
    #dictionary
    image_hemisphere_dict = {}
    image_hemisphere_dict['title'] = title
    image_hemisphere_dict['image_url'] =  image_link
    
    
    hemisphere_image_urls.append( image_hemisphere_dict)

print(hemisphere_image_urls)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-72-f4f2288ee35f> in <module>
#      17     #find image and link
#      18     image = hemp_image_soup.find('div', class_='downloads')
# ---> 19     image_link = hemp_image_soup.find('li').a['href']
#      20
#      21     #dictionary
#
# AttributeError: 'NoneType' object has no attribute 'a'
